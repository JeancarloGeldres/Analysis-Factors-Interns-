# %%
#Importamos todos los paquetes que vamos a necesitar
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from math import sqrt

# %%
# cargamos nuestro dataset
modelo = pd.read_csv('fourth_banks.csv',sep=',')

# %%
modelo_bcp = modelo[(modelo['banco']=='BCP')]
modelo_roa_bcp = modelo_bcp.groupby(['year', 'banco']).sum().reset_index()

modelo_bcp2 = modelo_roa_bcp[modelo_roa_bcp['banco'] == 'BCP']


plt.plot(modelo_bcp2['year'], modelo_bcp2['roa'], label='roa')
plt.plot(modelo_bcp2['year'], modelo_bcp2['pbi'], label='pbi')


plt.legend()
plt.xticks(rotation = 45)
plt.show()

# %%
plt.plot(modelo_bcp2['year'], modelo_bcp2['roa'], label='roa')
plt.plot(modelo_bcp2['year'], modelo_bcp2['size'], label='size')
plt.plot(modelo_bcp2['year'], modelo_bcp2['cap'], label='cap')
plt.plot(modelo_bcp2['year'], modelo_bcp2['dep'], label='dep')
plt.plot(modelo_bcp2['year'], modelo_bcp2['prov'], label='prov')

plt.legend()
plt.xticks(rotation = 45)
plt.show()

# %%
# si queremos mirar todas las correlaciones
corr = modelo_bcp.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, vmax=.8, linewidths=0.01,
            square=True,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x="banco", y="roa", data=modelo_bcp)
# Out:
# <AxesSubplot:xlabel='banco', ylabel='roa'>

# %%
modelo_bcp.groupby(['banco']).mean()['roa'].plot.barh()
# Out:
# <AxesSubplot:ylabel='banco'>

# %%
#Histograma para la evaluación del ROA
sns.distplot(modelo_bcp['roa'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='roa', ylabel='Density'>

# %%
sns.distplot(modelo_bcp['size'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='size', ylabel='Density'>

# %%
sns.distplot(modelo_bcp['cap'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cap', ylabel='Density'>

# %%
sns.distplot(modelo_bcp['loan'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='loan', ylabel='Density'>

# %%
sns.distplot(modelo_bcp['dep'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='dep', ylabel='Density'>

# %%
sns.distplot(modelo_bcp['prov'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='prov', ylabel='Density'>

# %%
sns.distplot(modelo_bcp['pbi'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='pbi', ylabel='Density'>

# %%
sns.lmplot(x='roa', y="loan", col = 'banco', data=modelo_bcp, truncate = True, scatter_kws={'s':0.8, 'alpha':0.3})

# %%
sns.lmplot(x='roa', y="pbi", col = 'banco', data=modelo_bcp, truncate = True, scatter_kws={'s':0.8, 'alpha':0.3})

# %%
sns.lmplot(x='i', y="pbi", col = 'banco', data=modelo_bcp, truncate = True, scatter_kws={'s':0.8, 'alpha':0.3})

# %%
print('minimo roa: ', modelo_bcp['roa'].min())
print('minimo size: ', modelo_bcp['size'].min())
print('minimo cap: ', modelo_bcp['cap'].min())
print('minimo loan: ', modelo_bcp['loan'].min())
print('minimo dep: ', modelo_bcp['dep'].min())
print('minimo prov: ', modelo_bcp['prov'].min())
print('minimo valor PBI:', modelo_bcp['pbi'].min())
print('minimo valor i:', modelo_bcp['i'].min())
# Out:
# minimo roa:  -25.2244435606913
# minimo size:  -21.8953322157899
# minimo cap:  -6.37860082304526
# minimo loan:  -8.29369027702253
# minimo dep:  -3.65607086714014
# minimo prov:  -40.4149352506346
# minimo valor PBI: -39.09
# minimo valor i: -80.0

# %%
print('maximo roa: ', modelo_bcp['roa'].max())
print('maximo size: ', modelo_bcp['size'].max())
print('maximo cap: ', modelo_bcp['cap'].max())
print('maximo loan: ', modelo_bcp['loan'].max())
print('maximo dep: ', modelo_bcp['dep'].max())
print('maximo prov: ', modelo_bcp['prov'].max())
print('maximo valor PBI:', modelo_bcp['pbi'].max())
print('maximo valor i:', modelo_bcp['i'].max())
# Out:
# maximo roa:  27.792864645669
# maximo size:  27.9805214567337
# maximo cap:  10.3217158176944
# maximo loan:  8.57721402900039
# maximo dep:  4.28511990612631
# maximo prov:  56.532369794327
# maximo valor PBI: 58.4903436908341
# maximo valor i: 7.69230769230769

# %%
print('promedio roa: ', modelo_bcp['roa'].mean())
print('promedio size: ', modelo_bcp['size'].mean())
print('promedio cap: ', modelo_bcp['cap'].mean())
print('promedio loan: ', modelo_bcp['loan'].mean())
print('promedio dep: ', modelo_bcp['dep'].mean())
print('promedio prov: ', modelo_bcp['prov'].mean())
print('promedio valor PBI:', modelo_bcp['pbi'].mean())
print('promedio valor i:', modelo_bcp['i'].mean())
# Out:
# promedio roa:  -1.2747354305589185
# promedio size:  0.900371198191074
# promedio cap:  0.1832507704384162
# promedio loan:  -0.47818707255377196
# promedio dep:  0.03149983482021725
# promedio prov:  1.0127395127326246
# promedio valor PBI: 1.8146330385020177
# promedio valor i: -2.0205745865839444

# %%
# cargamos las funciones necesarias
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
columnas_interes = ['size','cap','loan','dep','prov','pbi']
columnas_interes2 = ['roa']
X = modelo_bcp[columnas_interes]
y = modelo_bcp[columnas_interes2]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 3)

# %%
model = LinearRegression().fit(X_train, y_train)
model
# Out:
# LinearRegression()

# %%
model.score(X_train, y_train)
# Out:
# 0.6418502533349824

# %%
import statsmodels.api as sm
modelo_bcp_ols = sm.OLS(y_train, X_train)
results1 = modelo_bcp_ols.fit()
print(results1.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                    roa   R-squared (uncentered):                   0.617
# Model:                            OLS   Adj. R-squared (uncentered):              0.581
# Method:                 Least Squares   F-statistic:                              17.15
# Date:                Mon, 26 Jul 2021   Prob (F-statistic):                    1.06e-11
# Time:                        11:30:11   Log-Likelihood:                         -203.05
# No. Observations:                  70   AIC:                                      418.1
# Df Residuals:                      64   BIC:                                      431.6
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
columnas_interes3 = ['size','cap','loan','dep','prov','pbi','tc','i']
columnas_interes4 = ['roa']
X2 = modelo_bcp[columnas_interes3]
y2 = modelo_bcp[columnas_interes4]
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size = 0.2, random_state = 3)

# %%
model2 = LinearRegression().fit(X2_train, y2_train)
model2.score(X2_train, y2_train)
# Out:
# 0.6968669520159074

# %%
modelo_bcp_ols2 = sm.OLS(y2_train, X2_train)
results2 = modelo_bcp_ols2.fit()
print(results2.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                    roa   R-squared (uncentered):                   0.674
# Model:                            OLS   Adj. R-squared (uncentered):              0.632
# Method:                 Least Squares   F-statistic:                              16.01
# Date:                Mon, 26 Jul 2021   Prob (F-statistic):                    1.59e-12
# Time:                        11:30:18   Log-Likelihood:                         -197.39
# No. Observations:                  70   AIC:                                      410.8
# Df Residuals:                      62   BIC:                                      428.8
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
columnas_interes5 = ['loan','pbi']
columnas_interes6 = ['roa']
X3 = modelo_bcp[columnas_interes5]
y3 = modelo_bcp[columnas_interes6]
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size = 0.2, random_state = 3)

# %%
model3 = LinearRegression().fit(X3_train, y3_train)
model3.score(X3_train, y3_train)
# Out:
# 0.6106863677688079

# %%
modelo_bcp_ols3 = sm.OLS(y3_train, X3_train)
results3 = modelo_bcp_ols3.fit()
print(results3.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                    roa   R-squared (uncentered):                   0.593
# Model:                            OLS   Adj. R-squared (uncentered):              0.581
# Method:                 Least Squares   F-statistic:                              49.53
# Date:                Mon, 26 Jul 2021   Prob (F-statistic):                    5.35e-14
# Time:                        11:30:32   Log-Likelihood:                         -205.14
# No. Observations:                  70   AIC:                                      414.3
# Df Residuals:                      68   BIC:                                      418.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
print(results1.aic)
print(results2.aic)
print(results3.aic)
# Out:
# 418.1016592136043
# 410.78321588251555
# 414.28211541039764

# %%
# por fin, miramos histograma y boxplot de alcohol
sns.boxplot(y = 'roa', data = modelo_bcp)
plt.figure()

sns.distplot(modelo_bcp['roa'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='roa', ylabel='Density'>

# %%
modelo_bcp.groupby(['banco']).mean()['roa'].plot.bar()
# Out:
# <AxesSubplot:xlabel='banco'>

# %%
sns.lmplot(x='pbi', y="roa", col = 'banco', data=modelo_bcp, truncate = True, scatter_kws={'s':0.8, 'alpha':0.3})

# %%
# ratios for the whole dataset.
train_ratio = 0.5
test_ratio = 0.3
validation_ratio = 0.2

# using train test split method
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_ratio)

# validation ratio from remaining dataset.
remaining = 1 - test_ratio
validation_adjusted = validation_ratio / remaining

# train and validation splits
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_adjusted)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_validation.shape, y_validation.shape)
# Out:
# (43, 6) (43, 1) (27, 6) (27, 1) (18, 6) (18, 1)

# %%
# crreating model
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense 
from tensorflow.keras.optimizers import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-62-72ed2d684c98> in <module>
#       1 # crreating model
# ----> 2 import tensorflow as tf
#       3 import tensorflow.keras as keras
#       4 from tensorflow.keras.models import Sequential
#       5 from tensorflow.keras.layers import Dense
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
sns.histplot(modelo['roa'])
# Out:
# <AxesSubplot:xlabel='roa', ylabel='Count'>

# %%
sns.boxplot(x=modelo['roa'])
# Out:
# <AxesSubplot:xlabel='roa'>

# %%
modelo.columns
# Out:
# Index(['banco', 'mes', 'year', 'roa', 'size', 'cap', 'loan', 'dep', 'prov',
#        'pbi', 'tc', 'i', 'ftamn', 'tpmn'],
#       dtype='object')
